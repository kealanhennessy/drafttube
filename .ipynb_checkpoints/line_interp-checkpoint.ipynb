# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import interpolate
from planeInterp import *

# %%
baseline1 = planeInterpolator("1")
allpoints = baseline1.cone_interp() + baseline1.elbow_interp()
print(allpoints[20][1])

linePoints = []
for i in range(len(allpoints)):
    linePoints.append(allpoints[i][0])
plt.plot(linePoints[:][0], linePoints[:][2])
# Out:
# [0.1377269002824471, 0.005536320696968826, -0.12468884140253067]
