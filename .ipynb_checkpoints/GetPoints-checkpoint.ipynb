# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from finalpoints import *

# %%
M = FinalPoints()

# %%
equal1 = M.points(1, "e")

# %%
equal2 = M.points(4, "e")
equal3 = M.points(5, "e")
chebyshev1 =  M.points(1, "c")
chebyshev2 =  M.points(4, "c")
chebyshev3 =  M.points(5, "c")

# %%
ax2 = plt.axes(projection='3d')
x = []
y = []
z = []
for k in range(2000):
    x.extend([equal1[k][i][0] for i in range(360)])
    y.extend([equal1[k][i][1] for i in range(360)])
    z.extend([equal1[k][i][2] for i in range(360)])
ax2.plot3D(x, y, z, "r.")

# %%
plt.figure(figsize=(10,10))
plt.plot(x, z, ".")

# %%
allPointsPolar = []
for i in range(2000):
    points = np.asarray(equal1[i])
    x_mid = np.average(points[:,0])
    z_mid = np.average(points[:,2])
    for i in range(len(points)):
        points[i][0] = points[i][0] - x_mid
        points[i][2] = points[i][2] - z_mid

    ind = closest_index(points[:, 1], 0)
    if(not points[ind][0] == 0):
        phi = np.arctan(np.array(abs(points[ind][2]/points[ind][0]))) # angle of the plane
    else:
        phi = math.pi/2 # angle of the plane 
    
    y_axis = [0,1,0]
    for i in range(360):
        if phi == math.pi/2:
            points[i] = [points[i][2], points[i][1], points[i][0]]
        pt = points[i]
        dot_product = np.dot(y_axis, pt)
        y = np.array(y_axis)
        p = np.array(pt)
        theta_original = np.arccos(dot_product/(np.linalg.norm(p)*np.linalg.norm(y)))
        if p[0] > 0 and p[1] >= 0:
            theta = (math.pi/2) - theta_original
        elif p[1] >= 0:
            theta = (math.pi/2) + theta_original
        elif p[0] < 0 and p[1] < 0:
            theta = (math.pi/2) + theta_original
        else:
            theta = (5*math.pi/2) - theta_original
        r = np.linalg.norm(p)
        points[i] = [r, theta, 0]
    allPointsPolar.append(points)
plt.polar(points[:, 1],points[:, 0], '.')

# %%
def closest_index(lst, K):
    """Return the nearest value to integer K in a list of floating point values lst"""
    ind = min(range(len(lst)), key = lambda i: abs(lst[i] - K))
    return ind
