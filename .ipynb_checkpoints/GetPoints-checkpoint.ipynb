# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from finalpoints import *

# %%
M = FinalPoints()

# %%
equal1, angles = M.points(1, "e")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-4d97e9dbc70b> in <module>
# ----> 1 equal1, pointE, derE  = M.points(1, "e")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
equal2, pointE, derE = M.points(4, "e")
equal3, pointE, derE  = M.points(5, "e")
equal4, pointE, derE  = M.points(6, "e")

# %%
chebyshev1, pointC, derC =  M.points(1, "c")
chebyshev2, pointC, derC=  M.points(4, "c")
chebyshev3, pointC, derC =  M.points(5, "c")
chebyshev4, pointC, derC =  M.points(6, "c")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3cf843308191> in <module>
#       3 chebyshev1 =  M.points(1, "c")
#       4 chebyshev2 =  M.points(4, "c")
# ----> 5 chebyshev3 =  M.points(5, "c")
#
# ~\Documents\CFDResearch\DraftTubeProblem\drafttube\finalpoints.py in points(self, tubeNum, spacing)
#      59             for j in range(360):
#      60                 line = allLines[j]
# ---> 61                 point1, point2 = self.closest2index2(line, normal_vector, point, planeNum/numPlanes)
#      62                 line = line[point1] + [line[point2][i]-line[point1][i] for i in range(3)]
#      63                 t = (p_2[3] - (p_2[0]*line[0] +p_2[1]*line[1]+  +p_2[2]*line[2]))/(p_2[0]*line[3] +p_2[1]*line[4] + p_2[2]*line[5])
#
# ~\Documents\CFDResearch\DraftTubeProblem\drafttube\finalpoints.py in closest2index2(self, linePoints, normal_vector, point, a)
# ...

# %%
ax2 = plt.axes(projection='3d')
x = []
y = []
z = []
for k in range(100):
    x.extend([equal1[k][i][0] for i in range(360)])
    y.extend([equal1[k][i][1] for i in range(360)])
    z.extend([equal1[k][i][2] for i in range(360)])
ax2.plot3D(x, y, z, "r.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f47e8991a083> in <module>
#       4 z = []
#       5 for k in range(100):
# ----> 6     x.extend([equal1[k][i][0] for i in range(360)])
#       7     y.extend([equal1[k][i][1] for i in range(360)])
#       8     z.extend([equal1[k][i][2] for i in range(360)])
#
# <ipython-input-4-f47e8991a083> in <listcomp>(.0)
#       4 z = []
#       5 for k in range(100):
# ----> 6     x.extend([equal1[k][i][0] for i in range(360)])
#       7     y.extend([equal1[k][i][1] for i in range(360)])
#       8     z.extend([equal1[k][i][2] for i in range(360)])
#
# NameError: name 'equal1' is not defined

# %%
plt.figure(figsize=(25,25))
plt.plot(x, z, ".")
j = 0
for i in range(36000):
    if x[i] >= 5:
        print(i)
        j = j+1
plt.plot(pointE[0], pointE[1], "r.")

# %%
plt.figure(figsize=(25,25))
xc = []
yc = []
zc = []
for k in range(2000):
    xc.extend([chebyshev1[k][i][0] for i in range(360)])
    yc.extend([chebyshev1[k][i][1] for i in range(360)])
    zc.extend([chebyshev1[k][i][2] for i in range(360)])
plt.plot(xc, zc, ".")

# %%
allPoints = []
spacing = "c"
num = 1
allPoints, originPoints, originder = M.points(num, spacing) # call the previous function for the points here

for i in range(2000):
    points = allPoints[i] 
    for j in range(len(points)):
        points[j][0] = points[j][0] - originPoints[i][0]
        points[j][2] = points[j][2] - originPoints[i][1]
    
    phi = mayh.pi/2 - np.arctan(originder[i][1]/originder[i][0]) # angle of the plane

    y_axis = [0,1,0]
    for i in range(360):
        if phi == math.pi/2:
            points[i] = [points[i][2], points[i][1], points[i][0]]
        pt = points[i]
        dot_product = np.dot(y_axis, pt)
        y = np.array(y_axis)
        p = np.array(pt)
        theta_original = np.arccos(dot_product/(np.linalg.norm(p)*np.linalg.norm(y)))
        if p[0] > 0 and p[1] >= 0:
            theta = (math.pi/2) - theta_original
        elif p[1] >= 0:
            theta = (math.pi/2) + theta_original
        elif p[0] < 0 and p[1] < 0:
            theta = (math.pi/2) + theta_original
        else:
            theta = (5*math.pi/2) - theta_original
        r = np.linalg.norm(p)
        points[i] = [r, theta, 0]
    
    t = [i for i in range(360)]
    t_rad = [np.deg2rad(t[i]) for i in range(len(t))]
    f = self.interp(points)
    r_values = f(t_rad)
    
    for i in range(len(t)):
        point = [r_values[i]*np.cos(t_rad[i]), r_values[i]*np.sin(t_rad[i]), 0]
        x, y, z = self.plane_rotation(phi,point)
        xf = x + originPoints[i][0]
        zf = z + originPoints[i][1]
        points_final.append([xf, y, zf]) # 360 points
    allPoints.append(points_final) #2000 arrays of 360 points to be smoothed

# %%
def interp(self, points):
    """takes in the unorganized points at (0,0,0) and in r, theta and returns the interpolated functions"""
    r_theta = np.array([[points[i][0], points[i][1]] for i in range(len(points))]) # get r and theta from points
    sort = np.argsort(r_theta[:,1])
    r_theta_sorted = r_theta[sort,:] # sorted pairs
    r_plot = [r_theta_sorted[i][0] for i in range(len(r_theta_sorted))] # get r values form sorted
    theta_plot = [r_theta_sorted[i][1] for i in range(len(r_theta_sorted))] # get theta values from sorted
    f = interpolate.PchipInterpolator(theta_plot, r_plot)
    return f

def plane_rotation(self,phi, point):
    """rotate in 3d space takes in a point in cartesian coordinates 3d space and rotates it"""
    x = point[0]*np.cos(-phi) + point[2]*np.sin(-phi)
    y = point[1]
    z = -point[0]*np.sin(-phi) + point[2]*np.cos(-phi)
    return x, y, z
