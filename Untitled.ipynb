# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import interpolate
from planeInterpolator import *

# %%
baseline1 = planeInterpolator(1)
allpoints = baseline1.cone_interp()

linePoints = []
for i in range (0, 360, allpoints.len()):
    linePoints.append(allpoints(i))
plt.plot(linePoints[:][0], linePoints[:][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e192c0752f03> in <module>
#       1 baseline1 = planeInterpolator(1)
# ----> 2 allpoints = baseline1.cone_interp()
#       3
#       4 linePoints = []
#       5 for i in range (0, 360, allpoints.len()):
#
# TypeError: cone_interp() takes 0 positional arguments but 1 was given
