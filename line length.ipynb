# %%
import numpy as np
from reader import *
import matplotlib.pyplot as plt
import math
from scipy import interpolate

# %%
a = np.array((xa ,ya, za))
b = np.array((xb, yb, zb))
dist = np.linalg.norm(a-b) # Euclidean distance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-842cddd13c6e> in <module>
# ----> 1 a = np.array((xa ,ya, za))
#       2 b = np.array((xb, yb, zb))
#       3 dist = np.linalg.norm(a-b) # Euclidean distance
#
# NameError: name 'xa' is not defined

# %%
def weight(s, a, b):
    dist_a = np.linalg.norm(a-s)
    dist_b = np.linalg.norm(s-b)
    return
